# %% [markdown]
# <a href="https://colab.research.google.com/github/daini10421/Mini-Project-12-Tweets-Search-Download/blob/main/Mini_Project_12_Tweets_Search_Download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Install Package**

# %%
# !pip install tweepy

# %% [markdown]
# **Add Credentials**

# %%
access_token = "501682241-ZG1DshytyxUIUY8FXPoH2AXaDG9d5DQlORemfAzU"
access_token_secret = "mxwCYkDjgWG5qWy8ONtVs3j2lxiYSxyberVVa92jmd27z"
consumer_key = "we0Drpnvc1FZNazKkiKoFWlGf"
consumer_secret = "OXRvmJwM6ca9k90XMIMoktSCa5XvjNieqJivcfjbOAlmpO6RhH"

# %%
import os
import tweepy as tw
import pandas as pd

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# *Look for tweets and build a dataframe*

# %%
# Collect tweets
results = api.search_tweets(q='dengue', count=100)

# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in results], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(10))
# Out:
#                                               Tweets
# 0  RT @MinSaludCol: ¡No le des oportunidad al den...
# 1  De acuerdo al reporte actualizado de las últim...
# 2  RT @partidonovo30: NEGACIONISMO IDEOLÓGICO \n\...
# 3  RT @taoquei1: Lule nao quer comprar vacinas co...
# 4  RT @leandroruschel: "Genocídio"?\n\nRegime pet...
# 5  RT @gustavoramos: O governo LuIa não compra va...
# 6  RT @leandroruschel: "Genocídio"?\n\nRegime pet...
# 7  RT @leandroruschel: "Genocídio"?\n\nRegime pet...
# 8  @JAntonioMtzGa  confirmó primera defunción por...
# 9  RT @partidonovo30: NEGACIONISMO IDEOLÓGICO \n\...

# %%
data
# Out:
#                                                Tweets
# 0   RT @MinSaludCol: ¡No le des oportunidad al den...
# 1   De acuerdo al reporte actualizado de las últim...
# 2   RT @partidonovo30: NEGACIONISMO IDEOLÓGICO \n\...
# 3   RT @taoquei1: Lule nao quer comprar vacinas co...
# 4   RT @leandroruschel: "Genocídio"?\n\nRegime pet...
# ..                                                ...
# 95  RT @taoquei1: Lule nao quer comprar vacinas co...
# 96  RT @partidonovo30: NEGACIONISMO IDEOLÓGICO \n\...
# 97  RT @leandroruschel: "Genocídio"?\n\nRegime pet...
# 98  RT @taoquei1: Lule nao quer comprar vacinas co...
# 99  RT @taoquei1: Lule nao quer comprar vacinas co...
#
# [100 rows x 1 columns]

# %% [markdown]
# Find more at [Tweet Extraction](https://github.com/RodolfoFerro/pandas_twitter/blob/master/01-extracting-data.md)

# %%
data
# Out:
#                                                Tweets
# 0   RT @MinSaludCol: ¡No le des oportunidad al den...
# 1   De acuerdo al reporte actualizado de las últim...
# 2   RT @partidonovo30: NEGACIONISMO IDEOLÓGICO \n\...
# 3   RT @taoquei1: Lule nao quer comprar vacinas co...
# 4   RT @leandroruschel: "Genocídio"?\n\nRegime pet...
# ..                                                ...
# 95  RT @taoquei1: Lule nao quer comprar vacinas co...
# 96  RT @partidonovo30: NEGACIONISMO IDEOLÓGICO \n\...
# 97  RT @leandroruschel: "Genocídio"?\n\nRegime pet...
# 98  RT @taoquei1: Lule nao quer comprar vacinas co...
# 99  RT @taoquei1: Lule nao quer comprar vacinas co...
#
# [100 rows x 1 columns]

# %%
df=pd.read_csv('/content/estimated_numbers.csv')
df
# Out:
#                                 Country  Year              No. of cases  \
# 0                           Afghanistan  2017     630308[495000-801000]
# 1                               Algeria  2017                         0
# 2                                Angola  2017  4615605[3106000-6661000]
# 3                             Argentina  2017                         0
# 4                               Armenia  2017                         0
# ..                                  ...   ...                       ...
# 851  Venezuela (Bolivarian Republic of)  2010        57257[47000-74000]
# 852                            Viet Nam  2010        23062[21000-26000]
# 853                               Yemen  2010   1134927[611000-2686000]
# 854                              Zambia  2010  2169307[1449000-3095000]
# 855                            Zimbabwe  2010   1095083[606000-1717000]
#
#          No. of deaths  No. of cases_median  No. of cases_min  \
# ...

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
text = " ".join(review for review in df['Country'])
print("There are {} words in the combination of all reviews.".format(len(text)))
# Out:
# There are 9511 words in the combination of all reviews.

# %%
# Create stopword list:
stopwords = set(STOPWORDS)

# %%
# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords).generate(text)

# Display the generated image:
# the matplotlib way:
plt.figure( figsize=(10,10) )
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
wordcloud

# %%
df["mytext_new"] = df['Country'].str.lower().str.replace('[^\w\s]','')


new_df = df.mytext_new.str.split(expand=True).stack().value_counts().reset_index()

new_df.columns = ['Word', 'Frequency']

new_df.head(10)
# Out:
# <ipython-input-16-abf041deec36>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df["mytext_new"] = df['Country'].str.lower().str.replace('[^\w\s]','')
#          Word  Frequency
# 0    republic         80
# 1          of         56
# 2  democratic         24
# 3      guinea         24
# 4       south         16
# 5       sudan         16
# 6       korea         16
# 7     peoples         16
# 8       congo         16
# 9        arab         16
